# %%
# %matplotlib inline

# %% [markdown]
# One dimension shallow water, dam break case.
# ============================================
#
# This validation example use the shallow water equation to
# model a dam sudden break. The two part of the domain have different
# fluid depth and are separated by a well. A a certain instant, the wall
# disappear, leading to a discontinuity wave in direction of the lower depth,
# and a rarefaction wave in direction of the higher depth.
#
# The model reads as
#
# \begin{align}\begin{cases}
#         \frac{\partial h}{\partial t} + \frac{\partial h}{\partial x} &= 0 \\
#         \frac{\partial u}{\partial t} + u\,\frac{\partial u}{\partial x} &= -g\,\frac{\partial h}{\partial x}
#     \end{cases}\end{align}
#
# and the results are validated on the Randall J. LeVeque book (LeVeque, R. (2002).
# Finite Volume Methods for Hyperbolic Problems (Cambridge Texts in Applied Mathematics).
# Cambridge: Cambridge University Press. doi:10.1017/CBO9780511791253).

# %%
# !pip3 install scikit-fdiff
# Out:
# Collecting scikit-fdiff
#   Downloading scikit_fdiff-0.7.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 kB 1.0 MB/s eta 0:00:0000:01
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-fdiff) (3.6.3)
# Collecting dask
#   Downloading dask-2023.1.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 3.1 MB/s eta 0:00:00a 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 2.3 MB/s eta 0:00:00
# Collecting cloudpickle
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting python-forge
#   Downloading python_forge-18.6.0-py35-none-any.whl (31 kB)
# Collecting boltons
#   Downloading boltons-21.0.0-py2.py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.7/193.7 kB 2.4 MB/s eta 0:00:00a 0:00:01
# Collecting holoviews
#   Downloading holoviews-1.15.4-py2.py3-none-any.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 1.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: attrs in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-fdiff) (21.4.0)
# Collecting cached-property
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Collecting appdirs
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting cachetools
#   Downloading cachetools-5.2.1-py3-none-any.whl (9.3 kB)
# Collecting sympy<1.6
#   Downloading sympy-1.5.1-py2.py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 1.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyyaml in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-fdiff) (6.0)
# Collecting streamz
#   Downloading streamz-0.6.4-py2.py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Collecting joblib
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Collecting more-itertools
#   Downloading more_itertools-9.0.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Collecting path.py
#   Downloading path.py-12.5.0-py3-none-any.whl (2.3 kB)
# Collecting scipy
#   Downloading scipy-1.10.0-cp310-cp310-macosx_12_0_arm64.whl (28.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 972.9 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-fdiff) (1.24.1)
# Collecting xarray
#   Downloading xarray-2023.1.0-py3-none-any.whl (973 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.1/973.1 kB 835.3 kB/s eta 0:00:0000:0100:01
# Collecting loguru
#   Downloading loguru-0.6.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 594.2 kB/s eta 0:00:00a 0:00:01
# Collecting mpmath>=0.19
#   Downloading mpmath-1.2.1-py3-none-any.whl (532 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.6/532.6 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting toolz>=0.8.2
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 950.5 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: click>=7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from dask->scikit-fdiff) (8.1.3)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from dask->scikit-fdiff) (23.0)
# Collecting partd>=0.3.10
#   Downloading partd-1.3.0-py3-none-any.whl (18 kB)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2023.1.0-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 915.8 kB/s eta 0:00:00a 0:00:01
# Collecting pyviz-comms>=0.7.4
#   Downloading pyviz_comms-2.2.1-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 913.7 kB/s eta 0:00:00 0:00:01
# Collecting param<2.0,>=1.9.3
#   Downloading param-1.12.3-py2.py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.0/87.0 kB 734.3 kB/s eta 0:00:00a 0:00:01
# Collecting colorcet
#   Downloading colorcet-3.0.1-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.0 MB/s eta 0:00:000:00:0100:01
# Requirement already satisfied: pandas>=0.20.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from holoviews->scikit-fdiff) (1.5.2)
# Collecting panel>=0.13.1
#   Downloading panel-0.14.2-py2.py3-none-any.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 957.3 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->scikit-fdiff) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->scikit-fdiff) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->scikit-fdiff) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->scikit-fdiff) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->scikit-fdiff) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->scikit-fdiff) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->scikit-fdiff) (1.0.7)
# Collecting path
#   Downloading path-16.6.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: tornado in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from streamz->scikit-fdiff) (6.2)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from streamz->scikit-fdiff) (1.16.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from streamz->scikit-fdiff) (65.5.0)
# Collecting zict
#   Downloading zict-2.2.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=0.20.0->holoviews->scikit-fdiff) (2022.7.1)
# Collecting bokeh<2.5.0,>=2.4.0
#   Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 1.1 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: bleach in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from panel>=0.13.1->holoviews->scikit-fdiff) (5.0.1)
# Collecting pyct>=0.4.4
#   Downloading pyct-0.4.8-py2.py3-none-any.whl (15 kB)
# Collecting typing-extensions
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from panel>=0.13.1->holoviews->scikit-fdiff) (2.28.2)
# Collecting markdown
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Collecting heapdict
#   Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: Jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bokeh<2.5.0,>=2.4.0->panel>=0.13.1->holoviews->scikit-fdiff) (3.1.2)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bleach->panel>=0.13.1->holoviews->scikit-fdiff) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->panel>=0.13.1->holoviews->scikit-fdiff) (3.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->panel>=0.13.1->holoviews->scikit-fdiff) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->panel>=0.13.1->holoviews->scikit-fdiff) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->panel>=0.13.1->holoviews->scikit-fdiff) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh<2.5.0,>=2.4.0->panel>=0.13.1->holoviews->scikit-fdiff) (2.1.1)
# Installing collected packages: python-forge, mpmath, heapdict, fuzzywuzzy, cached-property, boltons, appdirs, zict, typing-extensions, tqdm, toolz, sympy, scipy, path, param, more-itertools, markdown, loguru, locket, joblib, fsspec, cloudpickle, cachetools, streamz, pyviz-comms, pyct, path.py, partd, bokeh, xarray, panel, dask, colorcet, holoviews, scikit-fdiff
# Successfully installed appdirs-1.4.4 bokeh-2.4.3 boltons-21.0.0 cached-property-1.5.2 cachetools-5.2.1 cloudpickle-2.2.1 colorcet-3.0.1 dask-2023.1.0 fsspec-2023.1.0 fuzzywuzzy-0.18.0 heapdict-1.0.1 holoviews-1.15.4 joblib-1.2.0 locket-1.0.0 loguru-0.6.0 markdown-3.4.1 more-itertools-9.0.0 mpmath-1.2.1 panel-0.14.2 param-1.12.3 partd-1.3.0 path-16.6.0 path.py-12.5.0 pyct-0.4.8 python-forge-18.6.0 pyviz-comms-2.2.1 scikit-fdiff-0.7.0 scipy-1.10.0 streamz-0.6.4 sympy-1.5.1 toolz-0.12.0 tqdm-4.64.1 typing-extensions-4.4.0 xarray-2023.1.0 zict-2.2.0

# %%
import pylab as pl
import pandas as pd
from skfdiff import Model, Simulation
import numpy as np
from scipy.signal import savgol_filter

shallow_water = Model(["-dx(h * u)", "-upwind(u, u, x, 1) - dxh"], ["h(x)", "u(x)"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pylab as pl
#       2 import pandas as pd
# ----> 3 from skfdiff import Model, Simulation
#       4 import numpy as np
#       5 from scipy.signal import savgol_filter
#
# ModuleNotFoundError: No module named 'skfdiff'

# %% [markdown]
# Filter post-process
# -------------------
#
# As the discontinuity will be still harsh to handle by a "simple" finite
# difference solver (a finite volume solver is usually the tool you will need),
# we will use a gaussian filter that will be applied to the fluid height. This
# will smooth the oscillation (generated by numerical errors). This can be seen
# as a way to introduce numerical diffusion to the system, often done by adding
# a diffusion term in the model. The filter has to be carefully tuned (the same
# way an artificial diffusion has its coefficient diffusion carefully chosen)
# to smooth the numerical oscillation without affecting the physical behavior
# of the simulation.

# %%
def filter_instabilities(simul):
    simul.fields["h"] = ("x",), savgol_filter(simul.fields["h"], 21, 4)


x, dx = np.linspace(-5, 5, 1000, retstep=True)
h = np.where(x < 0, 3, 1)
u = x * 0

init_fields = shallow_water.Fields(x=x, h=h, u=u)

simul = Simulation(
    shallow_water,
    t=0,
    dt=0.02,
    tmax=2,
    fields=init_fields,
    time_stepping=False,
    id="dambreak",
)

simul.add_post_process("filter", filter_instabilities)

container = simul.attach_container()

simul.run()

data = container.data.sel(t=[0, 0.5, 2], method="nearest")
fig, axs = pl.subplots(2, 2, sharex="all", figsize=(5.5, 2.5))
for i, t in enumerate(data.t):
    if i == 1:
        continue
    if i == 2:
        pl.sca(axs[i - 1, 0])
    else:
        pl.sca(axs[i, 0])
    data.sel(t=t).h.plot(color="black", label="Sol.")
    ref_data = pd.read_csv("valid_randall/dam_h%i.csv" % i)
    pl.scatter(ref_data.x, ref_data.h, color="red", marker=".", label="Ref.")
    pl.title("")
    pl.ylabel(r"$h$")
    pl.xlim(-5, 5)
    pl.ylim(0.5, 4)
    if i == 0:
        pl.legend()
    if i == 2:
        pl.sca(axs[i - 1, 1])
    else:
        pl.sca(axs[i, 1])
    (data.sel(t=t).h * data.sel(t=t).u).plot(color="black", label="Sol.")
    ref_data = pd.read_csv("valid_randall/dam_hu%i.csv" % i)
    pl.scatter(ref_data.x, ref_data.h, color="red", marker=".", label="Ref.")
    pl.title("")
    pl.ylabel(r"$u\,h$")
    pl.xlim(-5, 5)
    pl.ylim(-0.5, 1.5)
    pl.tight_layout()

pl.show()
